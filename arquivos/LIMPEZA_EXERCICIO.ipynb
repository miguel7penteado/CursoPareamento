# %% [markdown]
# # Exercício - Limpeza dos dados

# %%
import pandas as pd

# %% [markdown]
# 1. Faça a leitura dos arquivos "*tabela_final_telefone.csv*" e "*tabela_final_sem_telefone.csv*"
#
# Você pode utilizar a biblioteca Pandas
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
df_telefones =  none #Substitua "None" pela sua solução
df_sem_telefones = none

# %%
df_telefones.head() # Visualizamos as primeiras linhas do dataframe
# Out:
#               Nome  ...                Bairro
# 0      kyle tucker  ...           South Robin
# 1    daniel medina  ...          New Lisaview
# 2   benjamin yates  ...            West Scott
# 3    amy robertson  ...  South Kristenchester
# 4  maurice lambert  ...           North Susan
#
# [5 rows x 5 columns]

# %%
df_sem_telefones.head()
# Out:
#                Nome  ... Municipio
# 0      Kévin ThôMas  ...   3550308
# 1   Méghân AnDérsôn  ...   3300704
# 2    TiMothy Florés  ...   3300704
# 3    BénjaMin Yatés  ...   3550308
# 4  Michéllé Clayton  ...   3300704
#
# [5 rows x 3 columns]

# %% [markdown]
# Observe o formato dos campos relativos ao nome, endereço e município nas duas bases de dados.

# %% [markdown]
# 2. Uma das bases possui o código numérico dos municípios. É necessário deixar as duas bases no mesmo formato.
#
# Você pode consultar a tabela de códigos dos municípios
#
# https://www.ibge.gov.br/explica/codigos-dos-municipios.php

# %% [markdown]
# 2.1 Comece criando um dicionário.

# %%
# crie um dicionário chave: valor, conforme o exemplo abaixo

# %% [markdown]
# 2.2 Faça o mapeamento dos códigos para o nome dos municípios.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.map.html
#
# Observação: Lembre-se que você quer mapear apenas um campo específico do dataframe.
#
# Para acessar um atributo, faça: df_sem_telefones['nome_do_atributo']

# %%
df_sem_telefones.head()

# %% [markdown]
# 3. Observe os nomes em cada uma das bases. Como você poderia limpá-los?
# Faça a padronização dos nomes.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html

# %%
df_sem_telefones.Nome.loc[10] # perceba os múltiplos espaços

# %%
# Remova os espaços múltiplos

# %%
df_sem_telefones.head()

# %%
df_sem_telefones.Nome.loc[10] # veja se resolveu o problema dos espaços múltiplos

# %% [markdown]
# 4. Para o dataframe df_sem_telefones, quebre o endereço em número, logradouro e bairro.
#
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html
#
# 4.1 Comece quebrando em número e logradouro_bairro

# %%
df_sem_telefones.head()

# %% [markdown]
# 4.2 Agora quebre o atributo logradouro_bairro em logradouro e bairro, separados.

# %%
df_sem_telefones.head()

# %% [markdown]
# 5. Remova as colunas do dataframe que você não vai mais utilizar.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

# %%
df_sem_telefones.head()

# %% [markdown]
# 6. Converta todas as string do dataframe para letras maiúsculas
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.upper.html#pandas.Series.str.upper
#
# Você precisa alterar coluna a coluna? Tente aplicar uma função para todo o dataframe.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html

# %%
df_sem_telefones.head()

# %%
df_telefones.head()

# %%
df_telefones.head()

# %% [markdown]
# 7. Remova as pontuações dos logradouros.

# %%
df_sem_telefones.head()

# %% [markdown]
# 8. Na tabela *df_telefones*, faça também a limpeza dos telefones.

# %%
df_telefones.head()
